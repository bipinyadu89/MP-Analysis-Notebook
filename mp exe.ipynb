# %%
import xlrd
import pandas as pd
from openpyxl import load_workbook
wb = load_workbook('manpower.xlsx')
all=pd.DataFrame()
for ws in wb.worksheets[210:]:
    Title=ws.title
    df=pd.read_excel('manpower.xlsx',sheet_name=ws.title,skiprows=2,usecols='A:J',na_values=0)
    df.columns=['#','Machine','SKU','STDMP','G','A','B','C','TOTAL','REMARKS']
    TL=[[Title, df['TOTAL'].iloc[-1]]]
    all=all.append(TL,ignore_index= True)
all.columns=['Date','Manpower']
all
# Out:
#         Date  Manpower
# 0   01-12-18       133
# 1   02-12-18       108
# 2   03-12-18       131
# 3   04-12-18       137
# 4   06-12-18       145
# 5   07-12-18       140
# 6   08-12-18       116
# 7   09-12-18       104
# 8   10-12-18       138
# 9   11-12-18       132
# 10  12-12-18       136
# 11  13-12-18       132
# 12  14-12-18       137
# 13  15-12-18       147
# 14  16-12-18       127
# 15  17-12-18       144
# 16  18-12-18       132
# 17  19-12-18       163
# 18  20-12-18       162
# 19  21-12-18       160
# 20  22-12-18       159
# 21  23-12-18       134
# 22  24-12-18       158
# 23  25-12-18       150
# 24  26-12-18       157
# 25  27-12-18       157
# 26  28-12-18       142
# 27  29-12-18       141
# 28  30-12-18       127
# 29  31-12-18       111
# ..       ...       ...
# 42  14-01-19        46
# 43  16-01-19        36
# 44  17-01-19       107
# 45  18-01-19       117
# 46  19-01-19       129
# 47  20-01-19       120
# 48  21-01-19       146
# 49  22-01-19       141
# ...
